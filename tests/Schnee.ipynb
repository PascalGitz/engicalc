# %% [raw]
# ---
# title: "Einwirkung"
# subtitle: "Schnee"
# format:
#   typst:
#     toc: False
#     lang: de
#     columns: 1
#     execute:
#         warnings: false
#         echo: True
# ---

# %%
from engicalc import *
import numpy as np

# %% [markdown]
# Bezugshöhe

# %%
h_0 = 530*m
Cell(show_expression=False)
# Out:
# $$\begin{aligned}& h_{0}=530 \ \mathrm{m}\end{aligned}$$

# %% [markdown]
# Charakteristischer Wert der Schneelast auf horizontalem Gelände

# %%
s_k = max((1 + (h_0/(350*m))**2) * 0.4*kN/m**2 , 0.9*kN/m**2)
Cell(show_expression=False)
# Out:
# $$\begin{aligned}& s_{k}=\frac{1.32 \ \mathrm{kN}}{\mathrm{m}^{2}}\end{aligned}$$
