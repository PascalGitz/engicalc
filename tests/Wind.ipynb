# %%
from engicalc import *
import numpy as np

# %% [raw]
# ---
# title: "Einwirkung"
# subtitle: "Wind"
# format:
#   typst:
#     toc: False
#     lang: de
#     columns: 1
#     execute:
#         warnings: false
#         echo: True
# ---

# %% [markdown]
# Parameter

# %%
alpha_r = 0.19
z_g = 380*m
z = 6*m 
c_h = 1.6 * ((z/z_g)**alpha_r + 0.375)**2
Cell(show_expression=False, rows = 4)
# Out:
# $$\begin{aligned}& \alpha_{r}=0.19 \quad  z_{g}=380 \ \mathrm{m} \quad  z=6 \ \mathrm{m} \quad  c_{h}=1.1\end{aligned}$$

# %% [markdown]
# Staudruck

# %%
q_p0 = 0.90*kN/m**2
q_p = c_h * q_p0

Cell(show_expression=False, rows = 4)
# Out:
# $$\begin{aligned}& q_{p0}=\frac{0.9 \ \mathrm{kN}}{\mathrm{m}^{2}} \quad  q_{p}=\frac{0.99 \ \mathrm{kN}}{\mathrm{m}^{2}}\end{aligned}$$

# %% [markdown]
# Windkraft

# %%
c_f1 = 1.55
c_red = 1.00
c_d = 1.00
q_k1 = c_red * c_d * c_f1 * q_p 

Cell(show_expression=False, rows = 4)
# Out:
# $$\begin{aligned}& c_{f1}=1.55 \quad  c_{red}=1.0 \quad  c_{d}=1.0 \quad  q_{k1}=\frac{1.54 \ \mathrm{kN}}{\mathrm{m}^{2}}\end{aligned}$$
