# %%
from engicalc import *
import numpy as np

# %% [raw]
# ---
# title: "Einwirkung"
# subtitle: "Temperatur"
# format:
#   typst:
#     toc: False
#     lang: de
#     columns: 1
#     execute:
#         warnings: false
#         echo: True
# ---

# %% [markdown]
# Parameter

# %%
h = 0.95*m
alpha_T = 10*10**-6 / K
Delta_T1k = 20 *K
Delta_T21k = 12 *K
Delta_T22k = -4 *K

Cell(show_expression=False, rows = 1)
# Out:
# $$\begin{aligned}& h=0.95 \ \mathrm{m} \\ &  \alpha_{T}=\frac{0.0}{\mathrm{K}} \\ &  \Delta_{T1k}=20 \ \mathrm{K} \\ &  \Delta_{T21k}=12 \ \mathrm{K} \\ &  \Delta_{T22k}=- 4 \ \mathrm{K}\end{aligned}$$

# %% [markdown]
# Resultierende Dehnungen und Krümmungen

# %%
eps_x = (Delta_T1k * alpha_T).to(permille)
chi_T21 = (-Delta_T21k * alpha_T / h).to(1/m)
chi_T22 = (-Delta_T22k * alpha_T / h).to(1/m)
Cell(show_expression=False, rows = 1, precision=5)
# Out:
# $$\begin{aligned}& \varepsilon_{x}=0.2 \ ‰ \\ &  \chi_{T21}=- \frac{0.00013}{\mathrm{m}} \\ &  \chi_{T22}=\frac{4.0 \ 10^{-5}}{\mathrm{m}}\end{aligned}$$
