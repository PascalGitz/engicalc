# %% [raw]
# ---
# title: "Einwirkung Strassenverkehr"
# subtitle: "Nach SIA261 2020"
# format:
#   typst:
#     toc: false
#     columns: 1
#     execute:
#       echo: false
#     date-format: long
#     lang: de
#     include-in-header:
#       - text: "#set page(footer: context [])"
#     fig-align: center
#     margin:
#       x: 0.1cm
#       y: 0.1cm
# ---

# %%
from params import *

# %% [markdown]
# ### Anfahr- und Bremskräfte

# %% [markdown]
# Beiwerte und fiktiver Fahrstreifen 1

# %%
alpha_Q1 = 0.9
alpha_q1 = 0.9
Q_k1 = 300*kN
q_k1 = 9.*kN/m**2
b_1 = 3*m
l__Deckel

Cell(rows=2)
# Out:
# $$\begin{aligned}& \alpha_{Q1}=0.9 \quad  \alpha_{q1}=0.9 \\ &  Q_{k1}=300 \ \mathrm{kN} \quad  q_{k1}=\frac{9.0 \ \mathrm{kN}}{\mathrm{m}^{2}} \\ &  b_{1}=3 \ \mathrm{m} \quad  l^{Deckel}=6 \ \mathrm{m}\end{aligned}$$

# %% [markdown]
# Anfahr- und Bremskräfte

# %%
QA_k = 1.2*alpha_Q1 * Q_k1 + 0.1*alpha_q1 * q_k1 * b_1 * l__Deckel 
QB_k = QA_k
Cell()
# Out:
# $$\begin{aligned}& QA_{k}=1.2 \ \alpha_{Q1} \ Q_{k1} + 0.1 \ \alpha_{q1} \ q_{k1} \ b_{1} \ l^{Deckel}=338.58 \ \mathrm{kN} \\ &  QB_{k}=QA_{k}=338.58 \ \mathrm{kN}\end{aligned}$$
