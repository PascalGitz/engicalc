# %% [raw]
# ---
# title: "Einwirkung Temperatur"
# subtitle: "Nach SIA261 2020"
# format:
#   typst:
#     toc: false
#     columns: 1
#     execute:
#       echo: false
#     date-format: long
#     lang: de
#     include-in-header:
#       - text: "#set page(footer: context [])"
#     fig-align: center
#     margin:
#       x: 0.1cm
#       y: 0.1cm
# ---

# %%
from params import *

# %% [markdown]
# ### Baustoff

# %%
alpha_T
h__Deckel

Cell(precision=6)
# Out:
# $$\begin{aligned}& \alpha_{T}=\frac{1.0 \ 10^{-5}}{\mathrm{K}} \\ &  h^{Deckel}=500 \ \mathrm{mm}\end{aligned}$$

# %% [markdown]
# ### Gleichmässige Temperaturänderung

# %%
Delta_T1k = 20 *K
eps_T1k = (alpha_T * Delta_T1k).to(permille)
Cell()
# Out:
# $$\begin{aligned}& \Delta_{T1k}=20 \ \mathrm{K} \\ &  \varepsilon_{T1k}=\alpha_{T} \ \Delta_{T1k}=0.2 \ ‰\end{aligned}$$

# %% [markdown]
# ### Lineare Temperaturänderung

# %% [markdown]
# Oben warm

# %%
Delta_T21k = 12 *K
chi_T21k = (Delta_T21k*alpha_T / h__Deckel).to(1/m)
Cell(precision=5)
# Out:
# $$\begin{aligned}& \Delta_{T21k}=12 \ \mathrm{K} \\ &  \chi_{T21k}=\frac{\Delta_{T21k} \ \alpha_{T}}{h^{Deckel}}=\frac{0.00024}{\mathrm{m}}\end{aligned}$$

# %% [markdown]
# Oben kalt

# %%
Delta_T22k = -4 *K
chi_T22k = (Delta_T22k*alpha_T / h__Deckel).to(1/m)
Cell(precision=5)
# Out:
# $$\begin{aligned}& \Delta_{T22k}=- 4 \ \mathrm{K} \\ &  \chi_{T22k}=\frac{\Delta_{T22k} \ \alpha_{T}}{h^{Deckel}}=- \frac{8.0 \ 10^{-5}}{\mathrm{m}}\end{aligned}$$
