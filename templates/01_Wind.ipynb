# %% [raw]
# ---
# title: "Einwirkung Wind"
# subtitle: "Nach SIA261 2020"
# format:
#   typst:
#     toc: false
#     columns: 1
#     execute:
#       echo: false
#     date-format: long
#     lang: de
#     include-in-header:
#       - text: "#set page(footer: context [])"
#     fig-align: center
#     margin:
#       x: 0.1cm
#       y: 0.1cm
# ---

# %%
import numpy as np
from engicalc import *

# %% [markdown]
# ### Staudruck

# %%
q_p0 = 1.1*kN/m**2

Cell()
# Out:
# $$\begin{aligned}& q_{p0}=\frac{1.1 \ \mathrm{kN}}{\mathrm{m}^{2}}\end{aligned}$$

# %% [markdown]
# #### Profilbeiwert
#
# Geländekategorie III Ortschaften, freies Feld

# %%
z = 0*m
z_g = 450*m
alpha_r = 0.23
c_h = 1.6 * ((z / z_g)**alpha_r + 0.375)**2

Cell()
# Out:
# $$\begin{aligned}& z=0 \ \mathrm{m} \\ &  z_{g}=450 \ \mathrm{m} \\ &  \alpha_{r}=0.23 \\ &  c_{h}=1.6 \ \left(\left(\frac{z}{z_{g}}\right)^{\alpha_{r}} + 0.375\right)^{2}=0.22\end{aligned}$$

# %% [markdown]
# Staudruck

# %%
q_p = c_h * q_p0
Cell()
# Out:
# $$\begin{aligned}& q_{p}=c_{h} \ q_{p0}=\frac{0.25 \ \mathrm{kN}}{\mathrm{m}^{2}}\end{aligned}$$
